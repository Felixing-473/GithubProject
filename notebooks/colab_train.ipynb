# %% [markdown]
# # Colab 训练模板
# 这是一个可直接在 Google Colab 中运行的最小 PPO 训练模板。

# %%
# !git clone https://github.com/your-user/your-repo.git /content/project
# %cd /content/project
# !pip install -r requirements.txt

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
os.makedirs('/content/drive/MyDrive/flood_rl_checkpoints', exist_ok=True)
print('Checkpoint folder ready')

# %%
# !python train_ppo.py --config configs/default.json --seed 0 --total-steps 20000 --batch-size 1024 --minibatch 256 --lr 3e-4 --save-path /content/drive/MyDrive/flood_rl_checkpoints/ppo.pt
